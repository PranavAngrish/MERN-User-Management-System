# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip3 install news-please   #https://github.com/fhamborg/news-please
# Out:
# Collecting news-please
#   Downloading news_please-1.6.14-py3-none-any.whl.metadata (2.8 kB)
# Collecting Scrapy>=1.1.0 (from news-please)
#   Downloading Scrapy-2.12.0-py2.py3-none-any.whl.metadata (5.3 kB)
# Collecting PyMySQL>=0.7.9 (from news-please)
#   Downloading PyMySQL-1.1.1-py3-none-any.whl.metadata (4.4 kB)
# Collecting psycopg2-binary>=2.8.4 (from news-please)
#   Downloading psycopg2_binary-2.9.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting hjson>=1.5.8 (from news-please)
#   Downloading hjson-3.1.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting elasticsearch>=2.4 (from news-please)
#   Downloading elasticsearch-9.0.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: beautifulsoup4>=4.3.2 in /usr/local/lib/python3.11/dist-packages (from news-please) (4.13.4)
# Collecting readability-lxml>=0.6.2 (from news-please)
#   Downloading readability_lxml-0.8.4.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting langdetect>=1.0.7 (from news-please)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 48.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from news-please) (2.9.0.post0)
# Collecting plac>=0.9.6 (from news-please)
#   Downloading plac-1.4.5-py2.py3-none-any.whl.metadata (5.9 kB)
# Collecting dotmap>=1.2.17 (from news-please)
#   Downloading dotmap-1.3.30-py3-none-any.whl.metadata (3.2 kB)
# Collecting PyDispatcher>=2.0.5 (from news-please)
#   Downloading PyDispatcher-2.0.7-py3-none-any.whl.metadata (2.4 kB)
# Collecting warcio>=1.3.3 (from news-please)
#   Downloading warcio-1.7.5-py2.py3-none-any.whl.metadata (16 kB)
# Collecting ago>=0.0.9 (from news-please)
#   Downloading ago-0.1.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from news-please) (1.17.0)
# Requirement already satisfied: lxml>=3.3.5 in /usr/local/lib/python3.11/dist-packages (from news-please) (5.4.0)
# Collecting hurry.filesize>=0.9 (from news-please)
#   Downloading hurry.filesize-0.9.tar.gz (2.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting bs4 (from news-please)
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Collecting faust-cchardet>=2.1.18 (from news-please)
#   Downloading faust_cchardet-2.1.19-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.3 kB)
# Collecting boto3 (from news-please)
#   Downloading boto3-1.38.9-py3-none-any.whl.metadata (6.6 kB)
# Collecting redis (from news-please)
#   Downloading redis-6.0.0-py3-none-any.whl.metadata (10 kB)
# Collecting newspaper4k>=0.9.3.1 (from news-please)
#   Downloading newspaper4k-0.9.3.1-py3-none-any.whl.metadata (14 kB)
# Collecting lxml-html-clean>=0.1.1 (from news-please)
#   Downloading lxml_html_clean-0.4.2-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: typing-extensions>=4.7.0 in /usr/local/lib/python3.11/dist-packages (from news-please) (4.13.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.3.2->news-please) (2.7)
# Collecting elastic-transport<9,>=8.15.1 (from elasticsearch>=2.4->news-please)
#   Downloading elastic_transport-8.17.1-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from hurry.filesize>=0.9->news-please) (75.2.0)
# Requirement already satisfied: Pillow>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from newspaper4k>=0.9.3.1->news-please) (11.2.1)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.11/dist-packages (from newspaper4k>=0.9.3.1->news-please) (6.0.2)
# Collecting feedparser>=6.0.0 (from newspaper4k>=0.9.3.1->news-please)
#   Downloading feedparser-6.0.11-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: nltk>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from newspaper4k>=0.9.3.1->news-please) (3.9.1)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.11/dist-packages (from newspaper4k>=0.9.3.1->news-please) (2.0.2)
# Requirement already satisfied: pandas>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from newspaper4k>=0.9.3.1->news-please) (2.2.2)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from newspaper4k>=0.9.3.1->news-please) (2.32.3)
# Collecting tldextract>=2.0.1 (from newspaper4k>=0.9.3.1->news-please)
#   Downloading tldextract-5.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: chardet in /usr/local/lib/python3.11/dist-packages (from readability-lxml>=0.6.2->news-please) (5.2.0)
# Collecting cssselect (from readability-lxml>=0.6.2->news-please)
#   Downloading cssselect-1.3.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting Twisted>=21.7.0 (from Scrapy>=1.1.0->news-please)
#   Downloading twisted-24.11.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: cryptography>=37.0.0 in /usr/local/lib/python3.11/dist-packages (from Scrapy>=1.1.0->news-please) (43.0.3)
# Collecting itemloaders>=1.0.1 (from Scrapy>=1.1.0->news-please)
#   Downloading itemloaders-1.3.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting parsel>=1.5.0 (from Scrapy>=1.1.0->news-please)
#   Downloading parsel-1.10.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pyOpenSSL>=22.0.0 in /usr/local/lib/python3.11/dist-packages (from Scrapy>=1.1.0->news-please) (24.2.1)
# Collecting queuelib>=1.4.2 (from Scrapy>=1.1.0->news-please)
#   Downloading queuelib-1.8.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting service-identity>=18.1.0 (from Scrapy>=1.1.0->news-please)
#   Downloading service_identity-24.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting w3lib>=1.17.0 (from Scrapy>=1.1.0->news-please)
#   Downloading w3lib-2.3.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting zope.interface>=5.1.0 (from Scrapy>=1.1.0->news-please)
#   Downloading zope.interface-7.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.5 MB/s eta 0:00:00
# Collecting protego>=0.1.15 (from Scrapy>=1.1.0->news-please)
#   Downloading Protego-0.4.0-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting itemadapter>=0.1.0 (from Scrapy>=1.1.0->news-please)
#   Downloading itemadapter-0.11.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from Scrapy>=1.1.0->news-please) (24.2)
# Requirement already satisfied: defusedxml>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from Scrapy>=1.1.0->news-please) (0.7.1)
# Collecting botocore<1.39.0,>=1.38.9 (from boto3->news-please)
#   Downloading botocore-1.38.9-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->news-please)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.13.0,>=0.12.0 (from boto3->news-please)
#   Downloading s3transfer-0.12.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore<1.39.0,>=1.38.9->boto3->news-please) (2.4.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=37.0.0->Scrapy>=1.1.0->news-please) (1.17.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from elastic-transport<9,>=8.15.1->elasticsearch>=2.4->news-please) (2025.4.26)
# Collecting sgmllib3k (from feedparser>=6.0.0->newspaper4k>=0.9.3.1->news-please)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>=3.6.6->newspaper4k>=0.9.3.1->news-please) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>=3.6.6->newspaper4k>=0.9.3.1->news-please) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>=3.6.6->newspaper4k>=0.9.3.1->news-please) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk>=3.6.6->newspaper4k>=0.9.3.1->news-please) (4.67.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1.0->newspaper4k>=0.9.3.1->news-please) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1.0->newspaper4k>=0.9.3.1->news-please) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->newspaper4k>=0.9.3.1->news-please) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->newspaper4k>=0.9.3.1->news-please) (3.10)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.11/dist-packages (from service-identity>=18.1.0->Scrapy>=1.1.0->news-please) (25.3.0)
# Requirement already satisfied: pyasn1 in /usr/local/lib/python3.11/dist-packages (from service-identity>=18.1.0->Scrapy>=1.1.0->news-please) (0.6.1)
# Requirement already satisfied: pyasn1-modules in /usr/local/lib/python3.11/dist-packages (from service-identity>=18.1.0->Scrapy>=1.1.0->news-please) (0.4.2)
# Collecting requests-file>=1.4 (from tldextract>=2.0.1->newspaper4k>=0.9.3.1->news-please)
#   Downloading requests_file-2.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.11/dist-packages (from tldextract>=2.0.1->newspaper4k>=0.9.3.1->news-please) (3.18.0)
# Collecting automat>=24.8.0 (from Twisted>=21.7.0->Scrapy>=1.1.0->news-please)
#   Downloading automat-25.4.16-py3-none-any.whl.metadata (8.4 kB)
# Collecting constantly>=15.1 (from Twisted>=21.7.0->Scrapy>=1.1.0->news-please)
#   Downloading constantly-23.10.4-py3-none-any.whl.metadata (1.8 kB)
# Collecting hyperlink>=17.1.1 (from Twisted>=21.7.0->Scrapy>=1.1.0->news-please)
#   Downloading hyperlink-21.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting incremental>=24.7.0 (from Twisted>=21.7.0->Scrapy>=1.1.0->news-please)
#   Downloading incremental-24.7.2-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=37.0.0->Scrapy>=1.1.0->news-please) (2.22)
# Downloading news_please-1.6.14-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.2/96.2 kB 7.8 MB/s eta 0:00:00
# Downloading ago-0.1.0-py3-none-any.whl (6.5 kB)
# Downloading dotmap-1.3.30-py3-none-any.whl (11 kB)
# Downloading elasticsearch-9.0.1-py3-none-any.whl (905 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 905.5/905.5 kB 56.9 MB/s eta 0:00:00
# Downloading faust_cchardet-2.1.19-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.2/313.2 kB 23.7 MB/s eta 0:00:00
# Downloading hjson-3.1.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 4.6 MB/s eta 0:00:00
# Downloading lxml_html_clean-0.4.2-py3-none-any.whl (14 kB)
# Downloading newspaper4k-0.9.3.1-py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.6/296.6 kB 28.1 MB/s eta 0:00:00
# Downloading plac-1.4.5-py2.py3-none-any.whl (22 kB)
# Downloading psycopg2_binary-2.9.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 94.1 MB/s eta 0:00:00
# Downloading PyDispatcher-2.0.7-py3-none-any.whl (12 kB)
# Downloading PyMySQL-1.1.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 3.3 MB/s eta 0:00:00
# Downloading readability_lxml-0.8.4.1-py3-none-any.whl (19 kB)
# Downloading Scrapy-2.12.0-py2.py3-none-any.whl (311 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 24.1 MB/s eta 0:00:00
# Downloading warcio-1.7.5-py2.py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 kB 2.9 MB/s eta 0:00:00
# Downloading boto3-1.38.9-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 11.8 MB/s eta 0:00:00
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Downloading redis-6.0.0-py3-none-any.whl (268 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.9/268.9 kB 21.7 MB/s eta 0:00:00
# Downloading botocore-1.38.9-py3-none-any.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 94.6 MB/s eta 0:00:00
# Downloading cssselect-1.3.0-py3-none-any.whl (18 kB)
# Downloading elastic_transport-8.17.1-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 5.8 MB/s eta 0:00:00
# Downloading feedparser-6.0.11-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 8.0 MB/s eta 0:00:00
# Downloading itemadapter-0.11.0-py3-none-any.whl (11 kB)
# Downloading itemloaders-1.3.2-py3-none-any.whl (12 kB)
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading parsel-1.10.0-py2.py3-none-any.whl (17 kB)
# Downloading Protego-0.4.0-py2.py3-none-any.whl (8.6 kB)
# Downloading queuelib-1.8.0-py3-none-any.whl (13 kB)
# Downloading s3transfer-0.12.0-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 7.8 MB/s eta 0:00:00
# Downloading service_identity-24.2.0-py3-none-any.whl (11 kB)
# Downloading tldextract-5.3.0-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.4/107.4 kB 9.8 MB/s eta 0:00:00
# Downloading twisted-24.11.0-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 88.4 MB/s eta 0:00:00
# Downloading w3lib-2.3.1-py3-none-any.whl (21 kB)
# Downloading zope.interface-7.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (259 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.8/259.8 kB 20.8 MB/s eta 0:00:00
# Downloading automat-25.4.16-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 3.1 MB/s eta 0:00:00
# Downloading constantly-23.10.4-py3-none-any.whl (13 kB)
# Downloading hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 6.7 MB/s eta 0:00:00
# Downloading incremental-24.7.2-py3-none-any.whl (20 kB)
# Downloading requests_file-2.1.0-py2.py3-none-any.whl (4.2 kB)
# Building wheels for collected packages: hurry.filesize, langdetect, sgmllib3k
#   Building wheel for hurry.filesize (setup.py) ... done
#   Created wheel for hurry.filesize: filename=hurry.filesize-0.9-py3-none-any.whl size=4091 sha256=f09b0774c50cd31eb082d86fca67587db08d15aae88d0924bf5f72d5b2226832
#   Stored in directory: /root/.cache/pip/wheels/31/39/13/0c3f79f41ad006d53fc6ce22b24d3626edac8afb3a2026e511
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993223 sha256=327ab12c854b89eec8da16e1d99e359400cd874245fdc32fcf5d6cb7cf06019d
#   Stored in directory: /root/.cache/pip/wheels/0a/f2/b2/e5ca405801e05eb7c8ed5b3b4bcf1fcabcd6272c167640072e
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6046 sha256=d96bfd3140d0498f10806b97bdc9e6ca69c93bb86bdcedee3cf1308af706dc31
#   Stored in directory: /root/.cache/pip/wheels/3b/25/2a/105d6a15df6914f4d15047691c6c28f9052cc1173e40285d03
# Successfully built hurry.filesize langdetect sgmllib3k
# Installing collected packages: sgmllib3k, PyDispatcher, plac, hjson, faust-cchardet, dotmap, ago, zope.interface, warcio, w3lib, redis, queuelib, PyMySQL, psycopg2-binary, protego, lxml-html-clean, langdetect, jmespath, itemadapter, incremental, hyperlink, hurry.filesize, feedparser, elastic-transport, cssselect, constantly, automat, Twisted, requests-file, parsel, elasticsearch, bs4, botocore, tldextract, service-identity, s3transfer, readability-lxml, itemloaders, Scrapy, newspaper4k, boto3, news-please
# Successfully installed PyDispatcher-2.0.7 PyMySQL-1.1.1 Scrapy-2.12.0 Twisted-24.11.0 ago-0.1.0 automat-25.4.16 boto3-1.38.9 botocore-1.38.9 bs4-0.0.2 constantly-23.10.4 cssselect-1.3.0 dotmap-1.3.30 elastic-transport-8.17.1 elasticsearch-9.0.1 faust-cchardet-2.1.19 feedparser-6.0.11 hjson-3.1.0 hurry.filesize-0.9 hyperlink-21.0.0 incremental-24.7.2 itemadapter-0.11.0 itemloaders-1.3.2 jmespath-1.0.1 langdetect-1.0.9 lxml-html-clean-0.4.2 news-please-1.6.14 newspaper4k-0.9.3.1 parsel-1.10.0 plac-1.4.5 protego-0.4.0 psycopg2-binary-2.9.10 queuelib-1.8.0 readability-lxml-0.8.4.1 redis-6.0.0 requests-file-2.1.0 s3transfer-0.12.0 service-identity-24.2.0 sgmllib3k-1.0.0 tldextract-5.3.0 w3lib-2.3.1 warcio-1.7.5 zope.interface-7.2

# %% [markdown]
# ##Config
#
# save these configurations under /root/news-please-repo/config , in google colab when you open the files tab, go up one level, then create folder under the root directory name it "news-please-repo" then under it create folder named "config"

# %% [markdown]
# ### config.cfg
#
# save this cell to a file called /root/news-please-repo/config/config.cfg

# %%
# IMPORTANT
# All variables get parsed to the correct python-types (if not other declared)!
# So bools have to be True or False (uppercase-first),
# Floats need dots . (not comma)
# Ints are just normal ints
# dicts need to be like this { key: value }
# arrays need to be like this [ value1, value2, value3 ]
# All values in dicts and arrays will also be parsed.
# Everything that does not match any of the above criteria will be parsed as string.



[Crawler]

# GENERAL
# -------

# Crawling heuristics
# Default Crawlers:
# Possibilities: RecursiveCrawler, RecursiveSitemapCrawler, RssCrawler, SitemapCrawler, Download (./newsplease/crawler/spiders/-dir)
# default: SitemapCrawler
default = SitemapCrawler

# default:
# fallbacks = {
#     "RssCrawler": None,
#     "RecursiveSitemapCrawler": "RecursiveCrawler",
#     "SitemapCrawler": "RecursiveCrawler",
#     "RecursiveCrawler": None,
#     "Download": None
#     }
fallbacks = {
    "RssCrawler": None,
    "RecursiveSitemapCrawler": "RecursiveCrawler",
    "SitemapCrawler": "RecursiveCrawler",
    "RecursiveCrawler": None,
    "Download": None
    }

# Determines how many hours need to pass since the last download of a webpage
# to be downloaded again by the RssCrawler
# default: 6
hours_to_pass_for_redownload_by_rss_crawler = 6



# PROCESSES
# ---------

# Number of crawlers, that should crawl parallel
# not counting in daemonized crawlers
# default: 5
number_of_parallel_crawlers = 5

# Number of daemons, will be added to daemons.
# default: 10
number_of_parallel_daemons = 10



# SPECIAL CASES
# -------------

# urls which end on any of the following file extensions are ignored for recursive crawling
# default: "(pdf)|(docx?)|(xlsx?)|(pptx?)|(epub)|(jpe?g)|(png)|(bmp)|(gif)|(tiff)|(webp)|(avi)|(mpe?g)|(mov)|(qt)|(webm)|(ogg)|(midi)|(mid)|(mp3)|(wav)|(zip)|(rar)|(exe)|(apk)|(css)"
ignore_file_extensions = "(pdf)|(docx?)|(xlsx?)|(pptx?)|(epub)|(jpe?g)|(png)|(bmp)|(gif)|(tiff)|(webp)|(avi)|(mpe?g)|(mov)|(qt)|(webm)|(ogg)|(midi)|(mid)|(mp3)|(wav)|(zip)|(rar)|(exe)|(apk)|(css)"

# urls which match the following regex are ignored for recursive crawling
# default: ""
ignore_regex = ""

# Crawl the sitemaps of subdomains (if sitemap is enabled)
# If True, any SitemapCrawler will try to crawl on the sitemap of the given domain including subdomains instead of a domain's main sitemap.
# e.g. if True, a SitemapCrawler to be started on https://blog.zeit.de will try to crawl on the sitemap listed in http://blog.zeit.de/robots.txt. If not found, it will fall back to the False setting.
#      if False, a SitemapCrawler to be started on https://blog.zeit.de will try to crawl on the sitemap listed in http://zeit.de/robots.txt
# default: True
sitemap_allow_subdomains = True



[Heuristics]

# Enabled heuristics,
# Currently:
#    - og_type
#    - linked_headlines
#    - self_linked_headlines
#    - is_not_from_subdomain (with this setting enabled, it can be assured that only pages that aren't from a subdomain are downloaded)
#    - meta_contains_article_keyword
#    - crawler_contains_only_article_alikes
# (maybe not up-to-date, see ./newsplease/helper_classes/heursitics.py:
#  Every method not starting with __ should be a heuristic, except is_article)
# These heuristics can be overwritten by sitelist.json for each site
# default: {"og_type": True, "linked_headlines": "<=0.65", "self_linked_headlines": "<=0.56"}
enabled_heuristics = {"og_type": True, "linked_headlines": "<=0.65", "self_linked_headlines": "<=0.56"}

# Heuristics can be combined with others
# The heuristics need to have the same name as in enabled_heuristics
# Possible condition-characters / literals are: (, ), not, and, or
# All heuristics used here need to be enabled in enabled_heuristics as well!
# Examples:
#     "og_type and (self_linked_headlines or linked_headlines)"
#     "og_type"
# default: "og_type and (linked_headlines or self_linked_headlines)"
pass_heuristics_condition = "og_type and (linked_headlines or self_linked_headlines)"

# The maximum ratio of headlines divided by linked_headlines in a file

# The minimum number of headlines in a file to check for the ratio
# If less then this number are in the file, the file will pass the test.
# default: 5
min_headlines_for_linked_test = 5



[Files]

# GENERAL:
# -------

# Paths:
# toggles relative paths to be relative to the start_processes.py script (True) or relative to this config file (False)
# This does not work for this config's 'Scrapy' section which is always relative to the dir the start_processes.py script is called from
# Default: True
relative_to_start_processes_file = True



# INPUT:
# -----

# Here you can specify the input JSON-Filename
# default: sitelist.hjson
url_input_file_name = sitelist.hjson



# OUTPUT:
# ------

# Toggles whether leading './' or '.\' from above local_data_directory should be removed when saving the path into the Database
# True: ./data would become data
# default: True
working_path = "/content/drive/My Drive/Hindi_News"

# Following Strings in the local_data_directory will be replaced: (md5 hashes have a standard length of 32 chars)
#
# %working_path                           = the path specified in OUTPUT["working_path"]
# %time_download(<code>)                  = current time at download; will be replaced with strftime(<code>) where <code> is a string, explained further here: http://strftime.org/
# %time_execution(<code>)                 = current time at execution; will be replaced with strftime(<code>) where <code> is a string, explained further here: http://strftime.org/
# %timestamp_download                     = current time at download; unix-timestamp
# %timestamp_execution                    = current time at execution; unix-timestamp
# %domain(<size>)                         = first <size> chars of the domain of the crawled file (e.g. zeit.de)
# %appendmd5_domain(<size>)               = appends the md5 to %domain(<<size> - 32 (md5 length) - 1 (_ as separator)>) if domain is longer than <size>
# %md5_domain(<size>)                     = first <size> chars of md5 hash of %domain
# %full_domain(<size>)                    = first <size> chars of the domain including subdomains (e.g. panamapapers.sueddeutsche.de)
# %appendmd5_full_domain(<size>)          = appends the md5 to %full_domain(<<size> - 32 (md5 length) - 1 (_ as separator)>) if full_domain is longer than <size>
# %md5_full_domain(<size>)                = first <size> chars of md5 hash of %full_domain
# %subdomains(<size>)                     = first <size> chars of the domain's subdomains
# %appendmd5_subdomains(<size>)           = appends the md5 to %subdomains(<<size> - 32 (md5 length) - 1 (_ as separator)>) if subdomains is longer than <size>
# %md5_subdomains(<size>)                 = first <size> chars of md5 hash of %subdomains
# %url_directory_string(<size>)           = first <size> chars of the directories on the server (e.g. http://panamapapers.sueddeutsche.de/articles/56f2c00da1bb8d3c3495aa0a/ would evaluate to articles_56f2c00da1bb8d3c3495aa0a), no filename
# %appendmd5_url_directory_string(<size>) = appends the md5 to %url_directory_string(<<size> - 32 (md5 length) - 1 (_ as separator)>) if url_directory_string is longer than <size>
# %md5_url_directory_string(<size>)       = first <size> chars of md5 hash of %url_directory_string(<size>)
# %url_file_name(<size>)                  = first <size> chars of the file name (without type) on the server (e.g. http://www.spiegel.de/wirtschaft/soziales/ttip-dokumente-leak-koennte-ende-der-geheimhaltung-markieren-a-1090466.html would evaluate to ttip-dokumente-leak-koennte-ende-der-geheimhaltung-markieren-a-1090466, No filenames (indexes) will evaluate to index
# %md5_url_file_name(<size>)              = first <size> chars of md5 hash of %url_file_name
# %max_url_file_name                      = first x chars of %url_file_name, so the entire savepath has a length of the max possible length for a windows file system (260 characters - 1 <NUL>)
# %appendmd5_max_url_file_name            = appends the md5 to the first x - 32 (md5 length) - 1 (_ as separator) chars of %url_file_name if the entire savepath has a length longer than the max possible length for a windows file system (260 characters - 1 <NUL>)
#
# This path can be relative or absolute, though to be able to easily merge multiple data sets, it should be kept relative and consistent on all datasets.
# To be able to use cleanup commands, it should also start with a static folder name like 'data'.
#
# default: %working_path/data/%time_execution(%Y)/%time_execution(%m)/%time_execution(%d)/%appendmd5_full_domain(32)/%appendmd5_url_directory_string(60)_%appendmd5_max_url_file_name_%timestamp_download.html
local_data_directory = %working_path/data/%appendmd5_full_domain(32)/news%timestamp_download.html


# Toggles whether leading './' or '.\' from above local_data_directory should be removed when saving the path into the Database
# True: ./data would become data
# default: True
format_relative_path = True



[MySQL]

# MySQL-Connection required for saving meta-informations
host = localhost
port = 3306
db = 'news-please'
username = 'root'
password = 'password'



[Elasticsearch]

# Elasticsearch-Connection required for saving detailed meta-information
host = localhost
port = 9200
index_current = 'news-please'
index_archive = 'news-please-archive'

# Elasticsearch supports user authentication by CA certificates. If your database is protected by certificate
# fill in the following parameters, otherwise you can ignore them.
use_ca_certificates = False
ca_cert_path = /path/to/cacert.pem
client_cert_path = /path/to/client_cert.pem
client_key_path = /path/to/client_key.pem
username = 'root'
secret = 'password'

# Properties of the document type used for storage.
mapping = {"properties": {
    "url": {"type": "text","fields":{"keyword":{"type":"keyword"}}},
    "source_domain": {"type": "text","fields":{"keyword":{"type":"keyword"}}},
    "title_page": {"type": "text","fields":{"keyword":{"type":"keyword"}}},
    "title_rss": {"type": "text","fields":{"keyword":{"type":"keyword"}}},
    "localpath": {"type": "text","fields":{"keyword":{"type":"keyword"}}},
    "filename": {"type": "keyword"},
    "ancestor": {"type": "keyword"},
    "descendant": {"type": "keyword"},
    "version": {"type": "long"},
    "date_download": {"type": "date", "format":"yyyy-MM-dd HH:mm:ss"},
    "date_modify": {"type": "date", "format":"yyyy-MM-dd HH:mm:ss"},
    "date_publish": {"type": "date", "format":"yyyy-MM-dd HH:mm:ss"},
    "title": {"type": "text","fields":{"keyword":{"type":"keyword"}}},
    "description":  {"type": "text","fields":{"keyword":{"type":"keyword"}}},
    "text": {"type": "text"},
    "authors": {"type": "text","fields":{"keyword":{"type":"keyword"}}},
    "image_url":  {"type": "text","fields":{"keyword":{"type":"keyword"}}},
    "language": {"type": "keyword"}
    }}



[ArticleMasterExtractor]

# Choose which extractors you want to use.
#
# The Default is ['newspaper_extractor', 'readability_extractor', 'date_extractor', 'lang_detect_extractor'],
# which are all integrated extractors right now.
# Possibly extractors are 'newspaper_extractor' , 'readability_extractor' , 'date_extractor_extractor and 'lang_detect_extractor'
# Examples: -Only Newspaper and date_extractor: extractors = ['newspaper', 'date_extractor']
#           -Only Newspaper: extractors = ['newspaper']
extractors = ['newspaper_extractor', 'readability_extractor', 'date_extractor', 'lang_detect_extractor']



[DateFilter]

# If added to the pipeline, this module provides the means to filter the extracted articles based on the publishing date.
# Therefore this module has to be placed after the KM4 article extractor to access the publishing dates.
#
# All articles, with a publishing date outside of the given time interval are dropped. The dates used to specify the
# time interval are included and should follow this format: 'yyyy-mm-dd hh:mm:ss'.
#
# It is also possible to only define one date, assigning the other variable the value 'None' to create an half-bounded
# interval.

start_date = '1999-01-01 00:00:00'
end_date = '2999-12-31 00:00:00'

# If 'True' articles without a publishing date are dropped.
strict_mode = False



[Scrapy]

# Possible levels (must be UC-only): CRITICAL, ERROR, WARNING, INFO, DEBUG
# default: WARNING
LOG_LEVEL = INFO

# logformat, see https://docs.python.org/2/library/logging.html#logrecord-attributes
# default: [%(name)s:%(lineno)d|%(levelname)s] %(message)s
LOG_FORMAT = [%(name)s:%(lineno)d|%(levelname)s] %(message)s

# Can be a filename or None
# default: None
LOG_FILE = None

LOG_DATEFORMAT = %Y-%m-%d %H:%M:%S

LOG_STDOUT = False

LOG_ENCODING = utf-8

BOT_NAME = 'news-please'

SPIDER_MODULES = ['newsplease.crawler.spiders']
NEWSPIDER_MODULE = 'newsplease.crawler.spiders'

# Resume/Pause functionality activation
# default: .resume_jobdir
JOBDIRNAME = .resume_jobdir

# Respect robots.txt activation
# default: True
ROBOTSTXT_OBEY=False

# Maximum number of concurrent requests across all domains
# default: 16
# IMPORTANT: This setting does not work since each crawler has its own scrapy instance, but it might limit the concurrent_requests_per_domain if said setting has a higher number set than this one.
CONCURRENT_REQUESTS=16

# Maximum number of active requests per domain
# default: 4
CONCURRENT_REQUESTS_PER_DOMAIN=4

# User-agent activation
# default: 'news-please (+http://www.example.com/)'
USER_AGENT = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36"


# Pipeline activation
# Syntax: '<relative location>.<Pipeline name>': <Order of execution from 0-1000>
# default: {'newsplease.pipeline.pipelines.ArticleMasterExtractor':100, 'newsplease.crawler.pipeline.HtmlFileStorage':200, 'newsplease.pipeline.pipelines.JsonFileStorage': 300}
# Further options: 'newsplease.pipeline.pipelines.ElasticsearchStorage': 350
ITEM_PIPELINES = {'newsplease.pipeline.pipelines.ArticleMasterExtractor':100,
                  ##'newsplease.pipeline.pipelines.HtmlFileStorage':200,
                  'newsplease.pipeline.pipelines.JsonFileStorage':300
                  }

[Pandas]
file_name = "PandasStorage"

# %% [markdown]
# ### sitelist.hjson
#
# save this cell to a file called /root/news-please-repo/config/sitelist.hjson

# %% [markdown]
# here we scrap from 9 websites, to add new websites, these are good links that would prove helpful
#
# https://bharatdiscovery.org/india/%E0%A4%B8%E0%A4%AE%E0%A4%BE%E0%A4%9A%E0%A4%BE%E0%A4%B0_%E0%A4%AA%E0%A4%A4%E0%A5%8D%E0%A4%B0
# https://bharatdiscovery.org/india/%E0%A4%A8%E0%A4%88%E0%A4%A6%E0%A5%81%E0%A4%A8%E0%A4%BF%E0%A4%AF%E0%A4%BE
# https://bharatdiscovery.org/india/%E0%A4%86%E0%A4%9C
# https://www.naidunia.com/latest-news

# %%
# This is a HJSON-File, so comments and so on can be used! See https://hjson.org/
# Furthermore this is first of all the actual config file, but as default just filled with examples.
{
  # Every URL has to be in an array-object in "base_urls".
  # The same URL in combination with the same crawler may only appear once in this array.
  "base_urls" : [
	{
      # Start crawling from timesofindia
      "url": "https://www.livehindustan.com/",

      # Overwrite the default crawler and use th RecursiveCrawler instead
      "crawler": "RecursiveCrawler",

      # Because this site is weirt, use the
      # meta_contains_article_keyword-heuristic and disable all others because
      # overwrite will merge the defaults from "newscrawler.cfg" with
      # this
      "overwrite_heuristics": {
        "meta_contains_article_keyword": true,
        "og_type": false,
        "linked_headlines": false,
        "self_linked_headlines": false
      },
      # Also state that in the condition, all heuristics used in the condition
      # have to be activated in "overwrite_heuristics" (or default) as well.
      "pass_heuristics_condition": "meta_contains_article_keyword"
    },
	{
      # Start crawling from timesofindia
      "url": "https://www.jagran.com/",

      # Overwrite the default crawler and use th RecursiveCrawler instead
      "crawler": "RecursiveCrawler",

      # Because this site is weirt, use the
      # meta_contains_article_keyword-heuristic and disable all others because
      # overwrite will merge the defaults from "newscrawler.cfg" with
      # this
      "overwrite_heuristics": {
        "meta_contains_article_keyword": true,
        "og_type": false,
        "linked_headlines": false,
        "self_linked_headlines": false
      },
      # Also state that in the condition, all heuristics used in the condition
      # have to be activated in "overwrite_heuristics" (or default) as well.
      "pass_heuristics_condition": "meta_contains_article_keyword"
    },
	{
      # Start crawling from timesofindia
      "url": "https://aajtak.intoday.in/",

      # Overwrite the default crawler and use th RecursiveCrawler instead
      "crawler": "RecursiveCrawler",

      # Because this site is weirt, use the
      # meta_contains_article_keyword-heuristic and disable all others because
      # overwrite will merge the defaults from "newscrawler.cfg" with
      # this
      "overwrite_heuristics": {
        "meta_contains_article_keyword": true,
        "og_type": false,
        "linked_headlines": false,
        "self_linked_headlines": false
      },
      # Also state that in the condition, all heuristics used in the condition
      # have to be activated in "overwrite_heuristics" (or default) as well.
      "pass_heuristics_condition": "meta_contains_article_keyword"
    },
	{
      # Start crawling from timesofindia
      "url": "http://money.bhaskar.com/",

      # Overwrite the default crawler and use th RecursiveCrawler instead
      "crawler": "RecursiveCrawler",

      # Because this site is weirt, use the
      # meta_contains_article_keyword-heuristic and disable all others because
      # overwrite will merge the defaults from "newscrawler.cfg" with
      # this
      "overwrite_heuristics": {
        "meta_contains_article_keyword": true,
        "og_type": false,
        "linked_headlines": false,
        "self_linked_headlines": false
      },
      # Also state that in the condition, all heuristics used in the condition
      # have to be activated in "overwrite_heuristics" (or default) as well.
      "pass_heuristics_condition": "meta_contains_article_keyword"
    },
	{
      # Start crawling from timesofindia
      "url": "http://bhaskar.com/",

      # Overwrite the default crawler and use th RecursiveCrawler instead
      "crawler": "RecursiveCrawler",

      # Because this site is weirt, use the
      # meta_contains_article_keyword-heuristic and disable all others because
      # overwrite will merge the defaults from "newscrawler.cfg" with
      # this
      "overwrite_heuristics": {
        "meta_contains_article_keyword": true,
        "og_type": false,
        "linked_headlines": false,
        "self_linked_headlines": false
      },
      # Also state that in the condition, all heuristics used in the condition
      # have to be activated in "overwrite_heuristics" (or default) as well.
      "pass_heuristics_condition": "meta_contains_article_keyword"
    },
	{
      # Start crawling from timesofindia
      "url": "https://navbharattimes.indiatimes.com/",

      # Overwrite the default crawler and use th RecursiveCrawler instead
      "crawler": "RecursiveCrawler",

      # Because this site is weirt, use the
      # meta_contains_article_keyword-heuristic and disable all others because
      # overwrite will merge the defaults from "newscrawler.cfg" with
      # this
      "overwrite_heuristics": {
        "meta_contains_article_keyword": true,
        "og_type": false,
        "linked_headlines": false,
        "self_linked_headlines": false
      },
      # Also state that in the condition, all heuristics used in the condition
      # have to be activated in "overwrite_heuristics" (or default) as well.
      "pass_heuristics_condition": "meta_contains_article_keyword"
    },
	{
      # Start crawling from timesofindia
      "url": "http://naidunia.com/",

      # Overwrite the default crawler and use th RecursiveCrawler instead
      "crawler": "RecursiveCrawler",

      # Because this site is weirt, use the
      # meta_contains_article_keyword-heuristic and disable all others because
      # overwrite will merge the defaults from "newscrawler.cfg" with
      # this
      "overwrite_heuristics": {
        "meta_contains_article_keyword": true,
        "og_type": false,
        "linked_headlines": false,
        "self_linked_headlines": false
      },
      # Also state that in the condition, all heuristics used in the condition
      # have to be activated in "overwrite_heuristics" (or default) as well.
      "pass_heuristics_condition": "meta_contains_article_keyword"
    },
	{
      # Start crawling from timesofindia
      "url": "https://www.abplive.com/",

      # Overwrite the default crawler and use th RecursiveCrawler instead
      "crawler": "RecursiveCrawler",

      # Because this site is weirt, use the
      # meta_contains_article_keyword-heuristic and disable all others because
      # overwrite will merge the defaults from "newscrawler.cfg" with
      # this
      "overwrite_heuristics": {
        "meta_contains_article_keyword": true,
        "og_type": false,
        "linked_headlines": false,
        "self_linked_headlines": false
      },
      # Also state that in the condition, all heuristics used in the condition
      # have to be activated in "overwrite_heuristics" (or default) as well.
      "pass_heuristics_condition": "meta_contains_article_keyword"
    },
	{
      # Start crawling from timesofindia
      "url": "https://hindi.indiatvnews.com/",

      # Overwrite the default crawler and use th RecursiveCrawler instead
      "crawler": "RecursiveCrawler",

      # Because this site is weirt, use the
      # meta_contains_article_keyword-heuristic and disable all others because
      # overwrite will merge the defaults from "newscrawler.cfg" with
      # this
      "overwrite_heuristics": {
        "meta_contains_article_keyword": true,
        "og_type": false,
        "linked_headlines": false,
        "self_linked_headlines": false
      },
      # Also state that in the condition, all heuristics used in the condition
      # have to be activated in "overwrite_heuristics" (or default) as well.
      "pass_heuristics_condition": "meta_contains_article_keyword"
    }
	]
}

# %% [markdown]
# ##Run

# %%
# !news-please
# Out:
# Streaming output truncated to the last 5000 lines.
# [newsplease.helper_classes.sub_classes.heuristics_manager:49|INFO] Checking site: https://www.nytimes.com/athletic/5826104/2024/10/09/raiders-aidan-oconnell-starting-quarterback/
# [newsplease.pipeline.pipelines:537|INFO] Saving HTML to /root/news-please-repo/data/2025/05/06/faz.net/aktuell_wirtschaft_netzwirtschaft_der-facebook-boersengang_facebooks-erfolg-gewinn-mit-handy-werbung-13062066_1746519615.html
# [newsplease.pipeline.pipelines:562|INFO] Saving JSON to /root/news-please-repo/data/2025/05/06/faz.net/aktuell_wirtschaft_netzwirtschaft_der-facebook-boersengang_facebooks-erfolg-gewinn-mit-handy-werbung-13062066_1746519615.html.json
# [newsplease.helper_classes.sub_classes.heuristics_manager:49|INFO] Checking site: https://www.faz.net/aktuell/wirtschaft/thema/peter-thiel-p4
# [newsplease.helper_classes.sub_classes.heuristics_manager:49|INFO] Checking site: https://www.faz.net/aktuell/wirtschaft/thema/peter-thiel-p3
# [newsplease.pipeline.pipelines:537|INFO] Saving HTML to /root/news-please-repo/data/2025/05/06/zeit.de/news_2024-09_22_selenskyj-besteht-weiter-auf-freigabe-weitreichender-waffen_1746519617.html
# [newsplease.pipeline.pipelines:562|INFO] Saving JSON to /root/news-please-repo/data/2025/05/06/zeit.de/news_2024-09_22_selenskyj-besteht-weiter-auf-freigabe-weitreichender-waffen_1746519617.html.json
# [newsplease.helper_classes.sub_classes.heuristics_manager:49|INFO] Checking site: https://www.faz.net/aktuell/wirtschaft/thema/peter-thiel-p2
# [newsplease.helper_classes.sub_classes.heuristics_manager:49|INFO] Checking site: https://www.zeit.de/news/2024-09/22/mann-rast-mit-rund-100-stundenkilometern-durch-die-stadt
# [newsplease.helper_classes.sub_classes.heuristics_manager:49|INFO] Checking site: https://www
# [newsplease.pipeline.pipelines:537|INFO] Saving HTML to /root/news-please-repo/data/2025/05/06/nytimes.com/athletic_5474789_2024_05_07__1746520220.html
# [newsplease.pipeline.pipelines:562|INFO] Saving JSON to /root/news-please-repo/data/2025/05/06/nytimes.com/athletic_5474789_2024_05_07__1746520220.html.json
# [newsplease.helper_classes.sub_classes.heuristics_manager:49|INFO] Checking site: https://www.nytimes.com/books/best-sellers/2012/09/09/hardcover-advice/
# [newsplease.helper_classes.sub_classes.heuristics_manager:49|INFO] Checking site: https://www.faz.net/aktuell/politik/ausland/russland-vorwuerfe-gegen-politiker-wegen-belaestigung-15484518.html
# [newsplease.pipeline.pipelines:537|INFO] Saving HTML to /root/news-please-repo/data/2025/05/06/zeit.de/news_2025-04_11_sommertrend-25-eis-im-brioche-broetchen_1746520221.html
# [newsplease.pipeline.pipelines:562|INFO] Saving JSON to /root/news-please-repo/data/2025/05/06/zeit.de/news_2025-04_11_sommertrend-25-eis-im-brioche-broetchen_1746520221.html.json
# [scrapy.core.engine:435|INFO] Closing spider (shutdown)
# [newsplease.helper_classes.sub_classes.heuristics_manager:49|INFO] Checking site: https://www.zeit.de/news/2025-04/11/mindestlohnerhoehung-jeder-vierte-in-thueringen-betroffen
# [newsplease.pipeline.pipelines:537|INFO] Saving HTML to /root/news-please-repo/data/2025/05/06/nytimes.com/books_best-sellers_2012_09_09__1746520222.html
# [newsplease.pipeline.pipelines:562|INFO] Saving JSON to /root/news-please-repo/data/2025/05/06/nytimes.com/books_best-sellers_2012_09_09__1746520222.html.json
# [newsplease.helper_classes.sub_classes.heuristics_manager:49|INFO] Checking site: https://www.nytimes.com/books/best-sellers/2012/09/09/hardcover-fiction/
# [newsplease.__main__:285|INFO] Hard stop called by signal #2. Shutting down.Stack Frame: <frame at 0x1083ca3ecf40, file '/content/news-please/newsplease/__main__.py', line 206, code manage_crawlers>
# [newsplease.__main__:285|INFO] Hard stop called by signal #15. Shutting down.Stack Frame: <frame at 0x1083ca3ecf40, file '/content/news-please/newsplease/__main__.py', line 206, code manage_crawlers>
# [scrapy.crawler:445|INFO] Received SIGINT twice, forcing unclean shutdown
# [scrapy.crawler:445|INFO] Received SIGINT twice, forcing unclean shutdown
# [scrapy.crawler:445|INFO] Received SIGINT twice, forcing unclean shutdown
# [newsplease.pipeline.pipelines:537|INFO] Saving HTML to /root/news-please-repo/data/2025/05/06/zeit.de/news_2025-04_11_mindestlohnerhoehung-jeder-vierte-in-thueringen-betroffen_1746520223.html
# [newsplease.pipeline.pipelines:562|INFO] Saving JSON to /root/news-please-repo/data/2025/05/06/zeit.de/news_2025-04_11_mindestlohnerhoehung-jeder-vierte-in-thueringen-betroffen_1746520223.html.json
# [scrapy.core.downloader.handlers.http11:720|WARNING] Got data loss in https://www.zeit.de/news/2025-04/11/lebensmittel-aus-der-tiefkuehltruhe-sind-so-gefragt-wie-nie. If you want to process broken responses set the setting DOWNLOAD_FAIL_ON_DATALOSS = False -- This message won't be shown in further requests
# [scrapy.core.downloader.handlers.http11:720|WARNING] Got data loss in https://www.zeit.de/news/2025-04/11/delhi-und-karnataka-soeder-zieht-es-nach-indien. If you want to process broken responses set the setting DOWNLOAD_FAIL_ON_DATALOSS = False -- This message won't be shown in further requests
# [scrapy.core.downloader.handlers.http11:720|WARNING] Got data loss in https://www.zeit.de/news/2025-04/11/regionalzuege-zwischen-berlin-und-eberswalde-fallen-aus. If you want to process broken responses set the setting DOWNLOAD_FAIL_ON_DATALOSS = False -- This message won't be shown in further requests
# [scrapy.core.downloader.handlers.http11:720|WARNING] Got data loss in https://www.zeit.de/news/2025-04/11/kulturzug-zwischen-berlin-und-breslau-geht-in-zehnte-saison. If you want to process broken responses set the setting DOWNLOAD_FAIL_ON_DATALOSS = False -- This message won't be shown in further requests
# [newsplease.pipeline.pipelines:537|INFO] Saving HTML to /root/news-please-repo/data/2025/05/06/faz.net/aktuell_politik_ausland_russland-vorwuerfe-gegen-politiker-wegen-belaestigung-15484518_1746520222.html
# [newsplease.pipeline.pipelines:562|INFO] Saving JSON to /root/news-please-repo/data/2025/05/06/faz.net/aktuell_politik_ausland_russland-vorwuerfe-gegen-politiker-wegen-belaestigung-15484518_1746520222.html.json
# [newsplease.helper_classes.sub_classes.heuristics_manager:49|INFO] Checking site: https://www.faz.net/aktuell/feuilleton/debatten/russland-im-kampf-gegen-belaestigung-von-frauen-noch-am-anfang-15484395.html
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-3da2f5285761> in <cell line: 0>()
# ----> 1 get_ipython().system('news-please')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#     121       kwargs.update({'also_return_output': True})
#     122
# --> 123     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     124
#     125     if pip_warn:
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     452   # is expected to call this function, thus adding one level of nesting to the
#     453   # stack.
# --> 454   result = _run_command(
#     455       shell.var_expand(cmd, depth=2), clear_streamed_output=False
#     456   )
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_system_commands.py in _run_command(cmd, clear_streamed_output)
#     202       os.close(child_pty)
#     203
# --> 204       return _monitor_process(parent_pty, epoll, p, cmd, update_stdin_widget)
#     205   finally:
#     206     epoll.close()
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_system_commands.py in _monitor_process(parent_pty, epoll, p, cmd, update_stdin_widget)
#     232   while True:
#     233     try:
# --> 234       result = _poll_process(parent_pty, epoll, p, cmd, decoder, state)
#     235       if result is not None:
#     236         return result
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_system_commands.py in _poll_process(parent_pty, epoll, p, cmd, decoder, state)
#     280   output_available = False
#     281
# --> 282   events = epoll.poll()
#     283   input_events = []
#     284   for _, event in events:
#
# KeyboardInterrupt:

# %%
# !pip install indic-nlp-library
# Out:
# Collecting indic-nlp-library
#   Downloading indic_nlp_library-0.92-py3-none-any.whl.metadata (5.7 kB)
# Collecting sphinx-argparse (from indic-nlp-library)
#   Downloading sphinx_argparse-0.5.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting sphinx-rtd-theme (from indic-nlp-library)
#   Downloading sphinx_rtd_theme-3.0.2-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting morfessor (from indic-nlp-library)
#   Downloading Morfessor-2.0.6-py3-none-any.whl.metadata (628 bytes)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2025.2)
# Requirement already satisfied: sphinx>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from sphinx-argparse->indic-nlp-library) (8.2.3)
# Requirement already satisfied: docutils>=0.19 in /usr/local/lib/python3.11/dist-packages (from sphinx-argparse->indic-nlp-library) (0.21.2)
# Collecting sphinxcontrib-jquery<5,>=4 (from sphinx-rtd-theme->indic-nlp-library)
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->indic-nlp-library) (1.17.0)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.1.6)
# Requirement already satisfied: Pygments>=2.17 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.19.1)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.2.0)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.4.1)
# Requirement already satisfied: requests>=2.30.0 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.32.3)
# Requirement already satisfied: roman-numerals-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.1.0)
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (24.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.1->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2025.4.26)
# Downloading indic_nlp_library-0.92-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 3.4 MB/s eta 0:00:00
# Downloading Morfessor-2.0.6-py3-none-any.whl (35 kB)
# Downloading sphinx_argparse-0.5.2-py3-none-any.whl (12 kB)
# Downloading sphinx_rtd_theme-3.0.2-py2.py3-none-any.whl (7.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 85.9 MB/s eta 0:00:00
# Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 11.0 MB/s eta 0:00:00
# Installing collected packages: morfessor, sphinxcontrib-jquery, sphinx-argparse, sphinx-rtd-theme, indic-nlp-library
# Successfully installed indic-nlp-library-0.92 morfessor-2.0.6 sphinx-argparse-0.5.2 sphinx-rtd-theme-3.0.2 sphinxcontrib-jquery-4.1

# %%
# !pip uninstall -y news-please
# Out:
# Found existing installation: news-please 1.6.14
# Uninstalling news-please-1.6.14:
#   Successfully uninstalled news-please-1.6.14

# %%
# !git clone https://github.com/fhamborg/news-please.git
# Out:
# Cloning into 'news-please'...
# remote: Enumerating objects: 3584, done.
# remote: Counting objects: 100% (1178/1178), done.
# remote: Compressing objects: 100% (238/238), done.
# remote: Total 3584 (delta 1036), reused 948 (delta 940), pack-reused 2406 (from 2)
# Receiving objects: 100% (3584/3584), 3.14 MiB | 30.09 MiB/s, done.
# Resolving deltas: 100% (2396/2396), done.

# %%
# %cd news-please
# Out:
# /content/news-please

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/news-please
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Scrapy>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from news-please==1.6.13) (2.12.0)
# Requirement already satisfied: PyMySQL>=0.7.9 in /usr/local/lib/python3.11/dist-packages (from news-please==1.6.13) (1.1.1)
# Requirement already satisfied: psycopg2-binary>=2.8.4 in /usr/local/lib/python3.11/dist-packages (from news-please==1.6.13) (2.9.10)
# Requirement already satisfied: hjson>=1.5.8 in /usr/local/lib/python3.11/dist-packages (from news-please==1.6.13) (3.1.0)
# Requirement already satisfied: elasticsearch>=2.4 in /usr/local/lib/python3.11/dist-packages (from news-please==1.6.13) (9.0.1)
# Requirement already satisfied: beautifulsoup4>=4.3.2 in /usr/local/lib/python3.11/dist-packages (from news-please==1.6.13) (4.13.4)
# Requirement already satisfied: readability-lxml>=0.6.2 in /usr/local/lib/python3.11/dist-packages (from news-please==1.6.13) (0.8.4.1)
# Requirement already satisfied: langdetect>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from news-please==1.6.13) (1.0.9)
# Requirement already satisfied: python-dateutil>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from news-please==1.6.13) (2.9.0.post0)
# Requirement already satisfied: plac>=0.9.6 in /usr/local/lib/python3.11/dist-packages (from news-please==1.6.13) (1.4.5)
# Requirement already satisfied: dotmap>=1.2.17 in /usr/local/lib/python3.11/dist-packages (from news-please==1.6.13) (1.3.30)
# Requirement already satisfied: PyDispatcher>=2.0.5 in /usr/local/lib/python3.11/dist-packages (from news-please==1.6.13) (2.0.7)
# Requirement already satisfied: warcio>=1.3.3 in /usr/local/lib/python3.11/dist-packages (from news-please==1.6.13) (1.7.5)
# Requirement already satisfied: ago>=0.0.9 in /usr/local/lib/python3.11/dist-packages (from news-please==1.6.13) (0.1.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from news-please==1.6.13) (1.17.0)
# Requirement already satisfied: lxml>=3.3.5 in /usr/local/lib/python3.11/dist-packages (from news-please==1.6.13) (5.4.0)
# Requirement already satisfied: hurry.filesize>=0.9 in /usr/local/lib/python3.11/dist-packages (from news-please==1.6.13) (0.9)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.11/dist-packages (from news-please==1.6.13) (0.0.2)
# Requirement already satisfied: faust-cchardet>=2.1.18 in /usr/local/lib/python3.11/dist-packages (from news-please==1.6.13) (2.1.19)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.11/dist-packages (from news-please==1.6.13) (1.38.9)
# Requirement already satisfied: redis in /usr/local/lib/python3.11/dist-packages (from news-please==1.6.13) (6.0.0)
# Requirement already satisfied: newspaper4k>=0.9.3.1 in /usr/local/lib/python3.11/dist-packages (from news-please==1.6.13) (0.9.3.1)
# Requirement already satisfied: lxml-html-clean>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from news-please==1.6.13) (0.4.2)
# Requirement already satisfied: typing-extensions>=4.7.0 in /usr/local/lib/python3.11/dist-packages (from news-please==1.6.13) (4.13.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.3.2->news-please==1.6.13) (2.7)
# Requirement already satisfied: elastic-transport<9,>=8.15.1 in /usr/local/lib/python3.11/dist-packages (from elasticsearch>=2.4->news-please==1.6.13) (8.17.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from hurry.filesize>=0.9->news-please==1.6.13) (75.2.0)
# Requirement already satisfied: Pillow>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from newspaper4k>=0.9.3.1->news-please==1.6.13) (11.2.1)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.11/dist-packages (from newspaper4k>=0.9.3.1->news-please==1.6.13) (6.0.2)
# Requirement already satisfied: feedparser>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from newspaper4k>=0.9.3.1->news-please==1.6.13) (6.0.11)
# Requirement already satisfied: nltk>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from newspaper4k>=0.9.3.1->news-please==1.6.13) (3.9.1)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.11/dist-packages (from newspaper4k>=0.9.3.1->news-please==1.6.13) (2.0.2)
# Requirement already satisfied: pandas>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from newspaper4k>=0.9.3.1->news-please==1.6.13) (2.2.2)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from newspaper4k>=0.9.3.1->news-please==1.6.13) (2.32.3)
# Requirement already satisfied: tldextract>=2.0.1 in /usr/local/lib/python3.11/dist-packages (from newspaper4k>=0.9.3.1->news-please==1.6.13) (5.3.0)
# Requirement already satisfied: chardet in /usr/local/lib/python3.11/dist-packages (from readability-lxml>=0.6.2->news-please==1.6.13) (5.2.0)
# Requirement already satisfied: cssselect in /usr/local/lib/python3.11/dist-packages (from readability-lxml>=0.6.2->news-please==1.6.13) (1.3.0)
# Requirement already satisfied: Twisted>=21.7.0 in /usr/local/lib/python3.11/dist-packages (from Scrapy>=1.1.0->news-please==1.6.13) (24.11.0)
# Requirement already satisfied: cryptography>=37.0.0 in /usr/local/lib/python3.11/dist-packages (from Scrapy>=1.1.0->news-please==1.6.13) (43.0.3)
# Requirement already satisfied: itemloaders>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from Scrapy>=1.1.0->news-please==1.6.13) (1.3.2)
# Requirement already satisfied: parsel>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from Scrapy>=1.1.0->news-please==1.6.13) (1.10.0)
# Requirement already satisfied: pyOpenSSL>=22.0.0 in /usr/local/lib/python3.11/dist-packages (from Scrapy>=1.1.0->news-please==1.6.13) (24.2.1)
# Requirement already satisfied: queuelib>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from Scrapy>=1.1.0->news-please==1.6.13) (1.8.0)
# Requirement already satisfied: service-identity>=18.1.0 in /usr/local/lib/python3.11/dist-packages (from Scrapy>=1.1.0->news-please==1.6.13) (24.2.0)
# Requirement already satisfied: w3lib>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from Scrapy>=1.1.0->news-please==1.6.13) (2.3.1)
# Requirement already satisfied: zope.interface>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from Scrapy>=1.1.0->news-please==1.6.13) (7.2)
# Requirement already satisfied: protego>=0.1.15 in /usr/local/lib/python3.11/dist-packages (from Scrapy>=1.1.0->news-please==1.6.13) (0.4.0)
# Requirement already satisfied: itemadapter>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from Scrapy>=1.1.0->news-please==1.6.13) (0.11.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from Scrapy>=1.1.0->news-please==1.6.13) (24.2)
# Requirement already satisfied: defusedxml>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from Scrapy>=1.1.0->news-please==1.6.13) (0.7.1)
# Requirement already satisfied: botocore<1.39.0,>=1.38.9 in /usr/local/lib/python3.11/dist-packages (from boto3->news-please==1.6.13) (1.38.9)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from boto3->news-please==1.6.13) (1.0.1)
# Requirement already satisfied: s3transfer<0.13.0,>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from boto3->news-please==1.6.13) (0.12.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore<1.39.0,>=1.38.9->boto3->news-please==1.6.13) (2.4.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=37.0.0->Scrapy>=1.1.0->news-please==1.6.13) (1.17.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from elastic-transport<9,>=8.15.1->elasticsearch>=2.4->news-please==1.6.13) (2025.4.26)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.11/dist-packages (from feedparser>=6.0.0->newspaper4k>=0.9.3.1->news-please==1.6.13) (1.0.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>=3.6.6->newspaper4k>=0.9.3.1->news-please==1.6.13) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>=3.6.6->newspaper4k>=0.9.3.1->news-please==1.6.13) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>=3.6.6->newspaper4k>=0.9.3.1->news-please==1.6.13) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk>=3.6.6->newspaper4k>=0.9.3.1->news-please==1.6.13) (4.67.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1.0->newspaper4k>=0.9.3.1->news-please==1.6.13) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1.0->newspaper4k>=0.9.3.1->news-please==1.6.13) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->newspaper4k>=0.9.3.1->news-please==1.6.13) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->newspaper4k>=0.9.3.1->news-please==1.6.13) (3.10)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.11/dist-packages (from service-identity>=18.1.0->Scrapy>=1.1.0->news-please==1.6.13) (25.3.0)
# Requirement already satisfied: pyasn1 in /usr/local/lib/python3.11/dist-packages (from service-identity>=18.1.0->Scrapy>=1.1.0->news-please==1.6.13) (0.6.1)
# Requirement already satisfied: pyasn1-modules in /usr/local/lib/python3.11/dist-packages (from service-identity>=18.1.0->Scrapy>=1.1.0->news-please==1.6.13) (0.4.2)
# Requirement already satisfied: requests-file>=1.4 in /usr/local/lib/python3.11/dist-packages (from tldextract>=2.0.1->newspaper4k>=0.9.3.1->news-please==1.6.13) (2.1.0)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.11/dist-packages (from tldextract>=2.0.1->newspaper4k>=0.9.3.1->news-please==1.6.13) (3.18.0)
# Requirement already satisfied: automat>=24.8.0 in /usr/local/lib/python3.11/dist-packages (from Twisted>=21.7.0->Scrapy>=1.1.0->news-please==1.6.13) (25.4.16)
# Requirement already satisfied: constantly>=15.1 in /usr/local/lib/python3.11/dist-packages (from Twisted>=21.7.0->Scrapy>=1.1.0->news-please==1.6.13) (23.10.4)
# Requirement already satisfied: hyperlink>=17.1.1 in /usr/local/lib/python3.11/dist-packages (from Twisted>=21.7.0->Scrapy>=1.1.0->news-please==1.6.13) (21.0.0)
# Requirement already satisfied: incremental>=24.7.0 in /usr/local/lib/python3.11/dist-packages (from Twisted>=21.7.0->Scrapy>=1.1.0->news-please==1.6.13) (24.7.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=37.0.0->Scrapy>=1.1.0->news-please==1.6.13) (2.22)
# Installing collected packages: news-please
#   Running setup.py develop for news-please
# Successfully installed news-please-1.6.13

# %%
# %ls
# Out:
# drive/  news-please/  sample_data/

# %%
file_path = 'news-please/newsplease/pipeline/extractor/extractors/readability_extractor.py'

new_code = '''\
from copy import deepcopy
from readability import Document

from .abstract_extractor import AbstractExtractor
from ..article_candidate import ArticleCandidate


class ReadabilityExtractor(AbstractExtractor):
    """This class implements Readability as an article extractor. Readability is
    a subclass of Extractors and newspaper.Article.

    """

    def __init__(self):
        self.name = "readability"

    def extract(self, item):
      """Creates a readability document and returns an ArticleCandidate containing article title and text.

      :param item: A NewscrawlerItem to parse.
      :return: ArticleCandidate containing the recovered article data.
      """

      html_bytes = deepcopy(item['spider_response'].body)
      html_str = html_bytes.decode('utf-8', errors='ignore')  # decode bytes to string safely
      doc = Document(html_str)
      description = doc.summary()

      article_candidate = ArticleCandidate()
      article_candidate.extractor = self._name
      article_candidate.title = doc.short_title()
      article_candidate.description = description
      article_candidate.text = self._text(item)
      article_candidate.topimage = self._topimage(item)
      article_candidate.author = self._author(item)
      article_candidate.publish_date = self._publish_date(item)
      article_candidate.language = self._language(item)

      return article_candidate
'''

# Write the new code to the file
with open(file_path, 'w', encoding='utf-8') as f:
    f.write(new_code)

print(f"Updated {file_path} successfully.")
# Out:
# Updated news-please/newsplease/pipeline/extractor/extractors/readability_extractor.py successfully.
